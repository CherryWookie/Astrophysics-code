# %%
pip install galpy
# Out:
# Requirement already satisfied: galpy in /usr/local/lib/python3.10/dist-packages (1.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from galpy) (23.2)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.10/dist-packages (from galpy) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from galpy) (1.11.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from galpy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->galpy) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->galpy) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->galpy) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->galpy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->galpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->galpy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->galpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->galpy) (1.16.0)

# %% [markdown]
# Transforming coordinates in galpy:

# %%
import galpy.util.coords as coords
import astropy.units as u

# %% [markdown]
# Simple transformation from (ra, dec) --> (l, b) and (pmra*cos(dec), pmdec) --> (pmll_cos(b), pmbb). The argument, epoch = None, assumes the coordinates are given in the ICRS (International Celestial Reference System) that is currently adopted by the Gaia mission. The data are those of the star HD 39881.

# %%
c1 = coords.radec_to_lb(89.014303, 13.924912, degree=True, epoch=None)
print(c1)
c2 = coords.pmrapmdec_to_pmllpmbb(372.72, -483.69, 89.014303, 13.924912, degree=True, epoch=None)
print(c2)
# Out:
# (194.17212267729076, -5.565401458050028)
# (604.8848338960411, 83.60952231988207)

# %% [markdown]
# Transforming into Cartesian coordinates is made easier by creating an "Orbit" object.

# %%
from galpy.orbit import Orbit
R0, z0, V0, v_sun = 8.122*u.kpc, 0.0208*u.kpc, 235.*u.km/u.s, [12.9, 10.6, 7.78]*u.km / u.s
o = Orbit([89.014303*u.degree, 13.924912*u.degree,(37.59*u.mas).to(u.kpc, u.parallax()),
           372.72*u.mas/u.yr, -483.69*u.mas/u.yr, 0.37*u.km/u.s],radec=True, ro=R0, zo=z0, vo=V0, solarmotion=v_sun)

# %% [markdown]
# Now printing coordinates

# %%
o.x(), o.y(), o.z()
# Out:
# (8.147678092447057, -0.006482588778103208, 0.018285713304304868)

# %% [markdown]
# Printing the Cartesian velocity components:

# %%
print(o.vx(), o.vy(), o.vz())
# Out:
# -4.454684628497509 171.29916086110055 18.19390642030512

# %% [markdown]
# Printing the Cylindrical coordinate and velocity components:

# %%
print(o.R(), o.phi(), o.z())
print(o.vR(), o.vphi(), o.vz())
# Out:
# 8.147680671338255 -0.0007956361722496788 0.018285713304304868
# -4.590975012785152 21.023843378703404 18.19390642030512
